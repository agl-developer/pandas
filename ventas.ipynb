# %%
import pandas as pd

ventas = pd.read_csv('5-ventas.csv')

# %%
ventas.head(4)
# Out:
#                          Region           Country Item Type Sales Channel  \
# 0            Sub-Saharan Africa      South Africa    Fruits       Offline
# 1  Middle East and North Africa           Morocco   Clothes        Online
# 2         Australia and Oceania  Papua New Guinea      Meat       Offline
# 3            Sub-Saharan Africa          Djibouti   Clothes       Offline
#
#   Order Priority Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M  9/14/2013  667593514  10/19/2013        4611      109.28
# 2              M  5/15/2015  940995585    6/4/2015         360      421.89
# 3              H  5/17/2017  880811536    7/2/2017         562      109.28
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0       6.92       14862.69    11023.56       3839.13
# 1      35.84      503890.08   165258.24     338631.84
# 2     364.69      151880.40   131288.40      20592.00
# ...

# %%
ventas['ISV'] = round(ventas['Total Revenue'] * 0.15, 2)
ventas.head(4)
# Out:
#                          Region           Country Item Type Sales Channel  \
# 0            Sub-Saharan Africa      South Africa    Fruits       Offline
# 1  Middle East and North Africa           Morocco   Clothes        Online
# 2         Australia and Oceania  Papua New Guinea      Meat       Offline
# 3            Sub-Saharan Africa          Djibouti   Clothes       Offline
#
#   Order Priority Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M  9/14/2013  667593514  10/19/2013        4611      109.28
# 2              M  5/15/2015  940995585    6/4/2015         360      421.89
# 3              H  5/17/2017  880811536    7/2/2017         562      109.28
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit       ISV
# 0       6.92       14862.69    11023.56       3839.13   2229.40
# 1      35.84      503890.08   165258.24     338631.84  75583.51
# ...

# %%
ventas.groupby('Region').sum().sort_values('Total Revenue', ascending=False)
# Out:
#                                          Order ID  Units Sold    Unit Price  \
# Region
# Sub-Saharan Africa                 71654332227531   651852367  3.469013e+07
# Europe                             71148971508693   646416168  3.433635e+07
# Asia                               40140252332069   364122959  1.940473e+07
# Middle East and North Africa       34130863493639   310359376  1.653331e+07
# Central America and the Caribbean  29664930754835   269684393  1.438078e+07
# Australia and Oceania              22338067735380   202896949  1.077197e+07
# North America                       5988535663991    54235843  2.901109e+06
#
#                                       Unit Cost  Total Revenue    Total Cost  \
# Region
# Sub-Saharan Africa                 2.445275e+07   1.735603e+11  1.223593e+11
# Europe                             2.420046e+07   1.715413e+11  1.209122e+11
# Asia                               1.367497e+07   9.681620e+10  6.822308e+10
# ...

# %%
ventas[['Total Revenue', 'Total Cost']].shape
# Out:
# (500000, 2)

# %%
ventas.shape[1]
# Out:
# 15

# %%
ventas.groupby('Region').mean()[['Total Revenue', 'Total Cost', 'Total Profit']]

# %%
ventas_agrupadas = ventas.groupby(['Region', 'Sales Channel']).sum()[['Total Revenue', 'Total Cost', 'Total Profit']]

# %%
import matplotlib.pyplot as plt
