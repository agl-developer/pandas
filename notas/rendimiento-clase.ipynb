# %%
import pandas as pd
import matplotlib.pyplot as plt

rendimiento = pd.read_csv('rendimiento-alumnos.csv')

# %%
rendimiento.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
rendimiento[['gender', 'math score', 'reading score', 'writing score']]
# Out:
#      gender  math score  reading score  writing score
# 0    female          72             72             74
# 1    female          69             90             88
# 2    female          90             95             93
# 3      male          47             57             44
# 4      male          76             78             75
# ..      ...         ...            ...            ...
# 995  female          88             99             95
# 996    male          62             55             55
# 997  female          59             71             65
# 998  female          68             78             77
# 999  female          77             86             86
#
# [1000 rows x 4 columns]

# %%
rendimiento.groupby('gender')[['math score', 'reading score']].mean()
# Out:
#         math score  reading score
# gender
# female   63.633205      72.608108
# male     68.728216      65.473029

# %%
rendimiento['promedio total'] = round((rendimiento['math score'] + rendimiento['reading score'] + rendimiento['writing score']) / 3, 2)

# %%
rendimiento.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    promedio total
# 0           72.67
# 1           82.33
# 2           92.67
# 3           49.33
# 4           76.33

# %%
rendimiento.to_csv('resultado.csv')

# %%
rendimiento.groupby('gender')[['math score', 'reading score', 'writing score']].mean().plot(kind='bar')

# %%
rendimiento.groupby('parental level of education').mean().sort_values('promedio total', ascending=False)
# Out:
#                              math score  reading score  writing score  \
# parental level of education
# master's degree               69.745763      75.372881      75.677966
# bachelor's degree             69.389831      73.000000      73.381356
# associate's degree            67.882883      70.927928      69.896396
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268
# high school                   62.137755      64.704082      62.448980
#
#                              promedio total
# parental level of education
# master's degree                   73.598644
# bachelor's degree                 71.923983
# associate's degree                69.568964
# some college                      68.476106
# some high school                  65.107654
# high school                       63.097194

# %%
rendimiento.groupby('parental level of education').mean().sort_values('promedio total', ascending=False).plot(kind='bar')

# %%
rendimiento.groupby('race/ethnicity')['promedio total'].max()
# Out:
# race/ethnicity
# group A     96.33
# group B     96.67
# group C     98.67
# group D     99.00
# group E    100.00
# Name: promedio total, dtype: float64

# %%
rendimiento.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    promedio total
# 0           72.67
# 1           82.33
# 2           92.67
# 3           49.33
# 4           76.33

# %%
rendimiento[(rendimiento['reading score'] >= 90) & (rendimiento['writing score'] >= 85)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 38   female        group D          associate's degree  free/reduced
# 102  female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 957  female        group D             master's degree      standard
# 962  female        group E          associate's degree      standard
# 970  female        group D           bachelor's degree      standard
# 979  female        group C          associate's degree      standard
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
rendimiento.loc[rendimiento['reading score'] >= 90, ['gender', 'race/ethnicity']]
# Out:
#      gender race/ethnicity
# 1    female        group C
# 2    female        group B
# 6    female        group B
# 38   female        group D
# 102  female        group D
# ..      ...            ...
# 957  female        group D
# 962  female        group E
# 970  female        group D
# 979  female        group C
# 995  female        group E
#
# [79 rows x 2 columns]

# %%
rendimiento.loc[:, ['math score', 'reading score', 'writing score']]
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
rendimiento.loc[:, 'math score':'writing score']
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]
